# %%
import numpy as np

# %%
Test_c_grad=np.load('Test_c_grad.npy')
values=np.load('values.npy')
#output=np.load('dayinfo_outputs.npy')
Test_c_grad=np.round(Test_c_grad)

# %%
Test_c_grad.shape
# Out:
# (2, 21, 12, 6, 21, 12)

# %%
print(np.where(Test_c_grad==np.max(Test_c_grad)))
# Out:
# (array([0], dtype=int64), array([8], dtype=int64), array([1], dtype=int64), array([0], dtype=int64), array([8], dtype=int64), array([1], dtype=int64))

# %%
values.shape
# Out:
# (2, 21, 12)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
#plt.figure(figsize=(8,8))
f, axs = plt.subplots(figsize=(14,8),nrows=1,ncols=1)
sns.heatmap(values[0],annot=True,ax=axs,fmt='g').invert_yaxis()

# %%
data=Test_c_grad[0,8,2,0]

# %%
f, axs = plt.subplots(figsize=(14,8),nrows=1,ncols=1)
sns.heatmap(data,annot=True,ax=axs,fmt='g').invert_yaxis()

# %%
output.shape

# %%
output=np.reshape(output,(-1,2,21,12))

# %%
f, axs = plt.subplots(figsize=(14,8),nrows=1,ncols=1)
sns.heatmap(output[10,1],annot=True,ax=axs,fmt='g').invert_yaxis()
