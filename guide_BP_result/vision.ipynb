# %%
import numpy as np

# %%
Test_c_grad=np.load('Test_c_grad.npy')
values=np.load('values.npy')
input_Test_c=np.load('input_Test_c.npy')

# %% [markdown]
# 归一化

# %%
u=np.mean(Test_c_grad[0,5,3,0])
v=np.std(Test_c_grad[0,5,3,0])
Test_c_grad[0,5,3,0]=(Test_c_grad[0,5,3,0]-u)/v
Test_c_grad[0,5,3,0]=np.maximum(Test_c_grad[0,5,3,0],0)

# %%
input_Test_c.shape
# Out:
# (8, 19, 18)

# %%
input_Test_c=input_Test_c*51
Test_c_grad=np.round(Test_c_grad*51)

# %%
np.max(Test_c_grad)
# Out:
# 534.0

# %%
input_Test_c.shape
# Out:
# (8, 19, 18)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
#plt.figure(figsize=(8,8))
f, axs = plt.subplots(figsize=(14,8),nrows=1,ncols=1)
sns.heatmap(values[0],annot=True,ax=axs,fmt='g').invert_yaxis()

# %%
data1=Test_c_grad[0,5,3,0]
data2=Test_c_grad[0,5,3,3]
data3=Test_c_grad[0,5,3,5]

# %%
f, axs = plt.subplots(figsize=(18,8),nrows=1,ncols=1)
sns.heatmap(data1,annot=True,ax=axs,fmt='g').invert_yaxis()

# %%
data1=Test_c_grad[0,5,3,1]
data2=Test_c_grad[0,7,2,1]
data3=Test_c_grad[0,5,3,4]

# %%
f, axs = plt.subplots(figsize=(14,4),nrows=1,ncols=2)
sns.heatmap(data1,annot=True,ax=axs[0],fmt='g').invert_yaxis()
sns.heatmap(data2,annot=True,ax=axs[1],fmt='g').invert_yaxis()

# %%
f, axs = plt.subplots(figsize=(14,4),nrows=1,ncols=2)
sns.heatmap(input_Test_c[2],annot=True,ax=axs[0],fmt='g').invert_yaxis()
sns.heatmap(input_Test_c[3],annot=True,ax=axs[1],fmt='g').invert_yaxis()

# %% [markdown]
# 下一时刻的inflow 等于上一时刻的 outflow

# %%
f, axs = plt.subplots(figsize=(14,4),nrows=1,ncols=2)
sns.heatmap(input_Test_c[0],annot=True,ax=axs[0],fmt='g').invert_yaxis()
sns.heatmap(input_Test_c[1],annot=True,ax=axs[1],fmt='g').invert_yaxis()

# %%
m=np.load('res.npy')
f, axs = plt.subplots(figsize=(19,5),nrows=1,ncols=3)
sns.heatmap(m[0],annot=True,ax=axs[0],fmt='g').invert_yaxis()
sns.heatmap(m[1],annot=True,ax=axs[1],fmt='g').invert_yaxis()
sns.heatmap(m[2],annot=True,ax=axs[2],fmt='g').invert_yaxis()

# %%
import folium
import numpy as np
#colors =['#FF0000','#A52A2A ','#B22222 ','#8B0000 ','#800000']
m = folium.Map(location=[30.726490,104.042102], zoom_start=12)
lon =104.041
lat =30.655
for i in range(19):
    lon =104.041
    for j in range(18):
        index =np.random.randint(4)
        folium.vector_layers.Rectangle([[lat,lon],[lat+0.004,lon+0.005]],
        stroke=False,fill=True,fill_opacity=0.5).add_to(m)
        lon+=0.005
    lat+=0.004
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
in_dtw=np.load('in_5_3_dtw.npy')
out_dtw=np.load('out_5_3_dtw.npy')

# %%
in_dtw[in_dtw<0.1]=0
out_dtw[out_dtw<0.1]=0

# %%
f, axs = plt.subplots(figsize=(17,5),nrows=1,ncols=2)
sns.heatmap(in_dtw,annot=True,ax=axs[0],fmt='.2g').invert_yaxis()
sns.heatmap(out_dtw,annot=True,ax=axs[1],fmt='.2g').invert_yaxis()

# %%
import torch.nn as nn
loss = nn.CrossEntropyLoss()
input = torch.randn(3, 5, requires_grad=True)
target = torch.empty(3, dtype=torch.long).random_(5)
output = loss(input, target)
output.backward()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-351807357f96> in <module>
# ----> 1 import torch.nn as nn
#       2 loss = nn.CrossEntropyLoss()
#       3 input = torch.randn(3, 5, requires_grad=True)
#       4 target = torch.empty(3, dtype=torch.long).random_(5)
#       5 output = loss(input, target)
#
# ModuleNotFoundError: No module named 'torch'

# %%
data=np.load('../data/all_data_30days.npy')

# %%
data.shape

# %%
ins=data[:,0,:,:]

# %%
res=np.sum(ins,0)

# %%
res.shape

# %%
f, axs = plt.subplots(figsize=(19,8),nrows=1,ncols=1)
sns.heatmap(res,annot=True,ax=axs,fmt='g').invert_yaxis()

# %%
emissionprob=[[]*19*18]

# %%
emissionprob

# %%
a=np.random.rand(2,3)

# %%
a

# %%
a.reshape(-1,1)
